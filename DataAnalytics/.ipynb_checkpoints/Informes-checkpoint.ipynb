# %%
import numpy as np
import json 
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import SoundLoudness
import Emotions
import HandAnalytics
import GazeAnalytics
import Answers

# %%
useridx = 64
dataDir = "E:/Carrera/TFG/TFGAlgabaHernandez/DataAnalytics/Data/User"+str(useridx)

# %%
with open (dataDir+'/User'+str(useridx)+ 'TypeSound.json') as sound_file:
    data = np.array(json.load(sound_file)['data'])
    fig = SoundLoudness.DrawSoundLoudness(data, 0.05)
# Out:
# Tiempo de silencio:  15.950000000000001

# %%
with open (dataDir+'/User'+str(useridx)+ 'TypeGazes.json') as sound_file:
    data = np.array(json.load(sound_file)['data'])
    fig = GazeAnalytics.DrawGazeAnalytics(data, 1)
# Out:
# Ha mirado a publisher 1 durante:  0.0
# Ha mirado a publisher 2 durante:  0.09803921699523926
# Ha mirado a publisher 3 durante:  0.0
# Tiempo mirando a publishers:  0.09803921699523926

# %%
with open (dataDir+'/User'+str(useridx)+ 'TypeLeftHand.json') as sound_file:
    data = np.array(json.load(sound_file)['data'])
    fig = HandAnalytics.DrawHandAnalytics(data, 1)
# Out:
# -------Eje X --------
# Media:  0.0414936582920915
# Mediana:  0.029996871948242188
# Desviación Típica:  0.03815071487643286
# El coeficiente de variacion en eje X:  91.94348352674464 %
#
#
#
# -------Eje Y --------
# Media:  0.02262852555614407
# Mediana:  0.0115966796875
# Desviación Típica:  0.02871800231664809
# El coeficiente de variacion en eje Z:  126.91062104508445 %
#
#
#
# -------Eje Z --------
# Media:  0.0179075790663897
# Mediana:  0.013402938842773438
# Desviación Típica:  0.01408105553063922
# El coeficiente de variacion en eje Z:  78.6318210766279 %

# %%
with open (dataDir+'/User'+str(useridx)+ 'TypeRightHand.json') as sound_file:
    data = np.array(json.load(sound_file)['data'])
    fig = HandAnalytics.DrawHandAnalytics(data, 1)
# Out:
# -------Eje X --------
# Media:  0.02190276323738745
# Mediana:  0.01348114013671875
# Desviación Típica:  0.026651252281088632
# El coeficiente de variacion en eje X:  121.67986291152357 %
#
#
#
# -------Eje Y --------
# Media:  0.021035404528601694
# Mediana:  0.0096435546875
# Desviación Típica:  0.023708047530424978
# El coeficiente de variacion en eje Z:  112.70545093720119 %
#
#
#
# -------Eje Z --------
# Media:  0.017539202156713455
# Mediana:  0.01381683349609375
# Desviación Típica:  0.012291206880253409
# El coeficiente de variacion en eje Z:  70.07848344771328 %

# %%
with open (dataDir+'/User'+str(useridx)+ 'TypeVokaturi.json') as sound_file:
    data = np.array(json.load(sound_file)['data'])
    fig = Emotions.DrawEmotions(data)

# %%
with open (dataDir+'/User'+str(useridx)+ 'TypeAnswers.json') as sound_file:
    data = np.array(json.load(sound_file)['data'])
    fig = Answers.DrawAnswerAnalytics(data)
# Out:
# Resultado del PRCS:  33.0
